# %% [markdown]
# ## Data Loading and Exploration

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import seaborn as snb
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as scs

# %% [markdown]
# #### Import Dataset

# %%
df = pd.read_csv("stroke data.csv")

# %% [markdown]
# #### Dataset Head

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# #### Dataset Shape/Dimensions

# %%
df.shape
# Out:
# (5110, 12)

# %% [markdown]
# #### Dataset Data Types

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# #### Describe Dataset

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Count Plot for Smoking Status

# %%
plt.figure(figsize=(6,6)) #set figure size

ax = snb.countplot(x='smoking_status',hue='stroke',data=df) # create the countplot

#add labels to the bars
for container in ax.containers:
    ax.bar_label(container)

#set labels for x and y axes and title
plt.xlabel('smoking_status')
plt.ylabel('Frequency')
plt.title('Count Plot For Smoking Status',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Count Plot For Smoking Status')

# %% [markdown]
# #### Count Plot for Residence type

# %%
plt.figure(figsize=(6,6))

ax = snb.countplot(x='Residence_type',hue='stroke',data=df)

for container in ax.containers:
    ax.bar_label(container)

plt.xlabel('Residence_type')
plt.ylabel('Frequency')
plt.title('Count plot for Residence type')
# Out:
# Text(0.5, 1.0, 'Count plot for Residence type')

# %% [markdown]
# #### Count plot for work type

# %%
plt.figure(figsize=(6,6))


ax = snb.countplot(x='work_type',hue='stroke',data=df)

for container in ax.containers:
    ax.bar_label(container)
    
plt.xlabel('Work Type')
plt.ylabel('Frequency')
plt.title('Count Plot for Work Type')
# Out:
# Text(0.5, 1.0, 'Count Plot for Work Type')

# %% [markdown]
# #### Count plot for martial status

# %%
plt.figure(figsize=(6,6))

ax = snb.countplot(x='ever_married',hue='stroke',data=df)

for container in ax.containers:
    ax.bar_label(container)
    
plt.xlabel('Ever Married')
plt.ylabel('Frequency')
plt.title('Count Plot for Martial Status')
# Out:
# Text(0.5, 1.0, 'Count Plot for Martial Status')

# %% [markdown]
# #### Count Plot for Heart Disease

# %%
plt.figure(figsize=(6,6))

ax = snb.countplot(x='heart_disease',hue='stroke',data=df)

for conatiner  in ax.containers:
    ax.bar_label(container)
plt.xlabel('Heart Disease')
plt.ylabel('Frequency')
plt.title('Count Plot for Heart Disease')
# Out:
# Text(0.5, 1.0, 'Count Plot for Heart Disease')

# %% [markdown]
# #### Count plot for Hypertension

# %%
plt.figure(figsize=(6,6))

ax = snb.countplot(x='hypertension',hue='stroke',data=df)

for conatiner  in ax.containers:
    ax.bar_label(container)
plt.xlabel('hypertension')
plt.ylabel('Frequency')
plt.title('Count Plot for Hypertension')
# Out:
# Text(0.5, 1.0, 'Count Plot for Hypertension')
